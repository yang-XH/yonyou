# %%
import pandas as pd

# %%
data = pd.read_csv('../linliquan/sofy_classify/wrong_data_idcontent_yxh.csv', header=None, names = ['id', 'content'])

# %%
data[:5]
# Out:
#          id                                            content
# 0  38324538  贵州省广播电视信息网络股份有限公司贵阳市分公司2020年至2021年全省传输工程、管道工程施...
# 1  31756673  2019年视频会议系统建设采购框架入围项目中标候选人公示。发布时间：2019-04-12。项...
# 2  31756414  贵州省广播电视信息网络股份有限公司贵阳市分公司东原财富广场4号楼智能化工程项目中标结果公示，...
# 3  32818693  贵州省广播电视信息网络股份有限公司贵阳市分公司白云区新闻中心高清升级器材采购项目中标人公示。...
# 4  32818692  贵州省广播电视信息网络股份有限公司贵阳市分公司世界花都田园综合体智能化系统工程项目中标结果公...

# %%
data
# Out:
#                0                                                  1
# 0       38324538  贵州省广播电视信息网络股份有限公司贵阳市分公司2020年至2021年全省传输工程、管道工程施...
# 1       31756673  2019年视频会议系统建设采购框架入围项目中标候选人公示。发布时间：2019-04-12。项...
# 2       31756414  贵州省广播电视信息网络股份有限公司贵阳市分公司东原财富广场4号楼智能化工程项目中标结果公示，...
# 3       32818693  贵州省广播电视信息网络股份有限公司贵阳市分公司白云区新闻中心高清升级器材采购项目中标人公示。...
# 4       32818692  贵州省广播电视信息网络股份有限公司贵阳市分公司世界花都田园综合体智能化系统工程项目中标结果公...
# ...          ...                                                ...
# 587149  20623025  马鞍山福彩微信公众号平台开发运维及营销服务项目成交公告。一、项目相关情况，项目名称：马鞍山福...
# 587150  17696323  马鞍山市公共资源交易平台CA数字证书、电子签章服务及网上交易平台系统建设运维服务采购成交公告...
# 587151  25135380  马鞍山市总工会经费管理系统采购（MASCG-0-J-F-2018-1238）成交公告。马鞍山...
# 587152  31739007  雨山区党务公开平台建设项目成交公告。视力保护色：字体【大。中。小。】。一、项目相关情况，项目...
# 587153  24182666  山东中烟工业有限责任公司营销综合管理系统运维项目中标候选人公示。（招标编号：0627-18Z...
#
# [587154 rows x 2 columns]

# %%
data_sort = data.sort_values('id')

# %%
len(data_sort)
# Out:
# 587154

# %%
data_drop_duplicates = data_sort.drop_duplicates('id')

# %%
len(data_drop_duplicates)
# Out:
# 172427

# %%
data_drop_duplicates[:25]
# Out:
#              id                                            content
# 274513   100412  报送时间：2015年5月20日。谈判项目名称：宣化科技职业学院大门装修工程政府采购项目。谈判...
# 523475   100586  ，采购项目名称：中国科学院生物物理研究所蛋白质与多肽制备鉴定系统采购项目，采购人名称：中国科...
# 294375   100620  上海社发项目管理服务有限公司受。上海市奉贤区中医医院的委托，采用。竞争性磋商方式实施采购的。...
# 128427   100888  ，广州有德招标代理有限公司（以下简称“采购代理机构”）受广州经济技术开发区国有资产投资公司（...
# 105954   101009  北京中润达工程咨询有限公司受北京金隅科技学校的委托，就“北京金隅科技学校信息化建设---核心...
# 329665   101047  ZZFJ1504-DF13225。云南艺术学院教务教学管理系统升级建设单一来源采购。成。交。...
# 138439   101232  汕尾市公共资源交易中心受汕尾市公安局的委托，就“警用地理信息基础平台部署及应用软件开发”项目...
# 529876   101233  汕尾市公共资源交易中心受汕尾市公安局的委托，就“警用地理信息基础平台空间标准地址库数字采集”...
# 580449   101466  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 280230   101659  惠水县政府采购中心(招标代理机)构受惠水县教育局(采购单位)的委托，于2015年05月21日...
# 558325   101822  兰州理工大学数字设计与成型实验室改造及装修政府采购项目中标公告，（交易编号：GJ150209...
# 362658   101829  天祝县“全面改簿”项目计算机教室、多媒体教室、学生课桌凳、图书、学生宿舍用床采购项目（第一、...
# 57000    102179  [点击下载]。[点击下载]。华春建设工程项目管理有限责任公司受平顶山高新技术产业开发区住房建...
# ...

# %%
data_drop_duplicates.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted.csv', index=False)

# %%
data1 = pd.read_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted.csv')

# %%
data1[:5]
# Out:
#        id                                            content
# 0  100412  报送时间：2015年5月20日。谈判项目名称：宣化科技职业学院大门装修工程政府采购项目。谈判...
# 1  100586  ，采购项目名称：中国科学院生物物理研究所蛋白质与多肽制备鉴定系统采购项目，采购人名称：中国科...
# 2  100620  上海社发项目管理服务有限公司受。上海市奉贤区中医医院的委托，采用。竞争性磋商方式实施采购的。...
# 3  100888  ，广州有德招标代理有限公司（以下简称“采购代理机构”）受广州经济技术开发区国有资产投资公司（...
# 4  101009  北京中润达工程咨询有限公司受北京金隅科技学校的委托，就“北京金隅科技学校信息化建设---核心...

# %%
len(data1)
# Out:
# 172427

# %%
data_0 = data1[:86213]

# %%
data_1 = data1[86213:]

# %%
data_1[:5]
# Out:
#              id                                            content
# 86213  26074897  混合动力总成试验台（升级）台架系统升级评标结果公示公告(1)。项目名称：混合动力总成试验台（...
# 86214  26074900  系统硬件中标候选人公示。黑龙江省招标公司受哈尔滨东安汽车发动机制造有限公司的委托，就系统硬件...
# 86215  26074903  系统硬件中标结果公示。招标编号：HTC-183031，招标内容：系统硬件，中标人：黑龙江惠诚...
# 86216  26074951  哈尔滨东安汽车发动机制造有限公司6AT照相防错系统采购项目评标结果公示。本项目只有3家投标人...
# 86217  26074953  哈尔滨东安汽车发动机制造有限公司6AT照相防错系统采购项目（NKMZB18135）中标结果公...

# %%
data_0.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted_00.csv', index=False)

# %%
data_1.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted_01.csv', index=False)

# %%
data3 = pd.read_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted_01.csv')

# %%
data3[:5]
# Out:
#          id                                            content
# 0  26074897  混合动力总成试验台（升级）台架系统升级评标结果公示公告(1)。项目名称：混合动力总成试验台（...
# 1  26074900  系统硬件中标候选人公示。黑龙江省招标公司受哈尔滨东安汽车发动机制造有限公司的委托，就系统硬件...
# 2  26074903  系统硬件中标结果公示。招标编号：HTC-183031，招标内容：系统硬件，中标人：黑龙江惠诚...
# 3  26074951  哈尔滨东安汽车发动机制造有限公司6AT照相防错系统采购项目评标结果公示。本项目只有3家投标人...
# 4  26074953  哈尔滨东安汽车发动机制造有限公司6AT照相防错系统采购项目（NKMZB18135）中标结果公...

# %%
len(data3)
# Out:
# 86214

# %%
data3
# Out:
#                                                       id  \
# 0                                               26074897
# 1                                               26074900
# 2                                               26074903
# 3                                               26074951
# 4                                               26074953
# ...                                                  ...
# 86209  http://www.jszhaobiao.com/result-detail-117750...
# 86210  http://www.jszhaobiao.com/result-detail-118114...
# 86211  http://www.jszhaobiao.com/result-detail-120053...
# 86212  http://www.jszhaobiao.com/result-detail-121710...
# 86213                                                 id
#
#                                                  content
# 0      混合动力总成试验台（升级）台架系统升级评标结果公示公告(1)。项目名称：混合动力总成试验台（...
# 1      系统硬件中标候选人公示。黑龙江省招标公司受哈尔滨东安汽车发动机制造有限公司的委托，就系统硬件...
# 2      系统硬件中标结果公示。招标编号：HTC-183031，招标内容：系统硬件，中标人：黑龙江惠诚...
# ...

# %%
data1
# Out:
#                                                        id  \
# 0                                                  100412
# 1                                                  100586
# 2                                                  100620
# 3                                                  100888
# 4                                                  101009
# ...                                                   ...
# 172422  http://www.jszhaobiao.com/result-detail-117750...
# 172423  http://www.jszhaobiao.com/result-detail-118114...
# 172424  http://www.jszhaobiao.com/result-detail-120053...
# 172425  http://www.jszhaobiao.com/result-detail-121710...
# 172426                                                 id
#
#                                                   content
# 0       报送时间：2015年5月20日。谈判项目名称：宣化科技职业学院大门装修工程政府采购项目。谈判...
# 1       ，采购项目名称：中国科学院生物物理研究所蛋白质与多肽制备鉴定系统采购项目，采购人名称：中国科...
# 2       上海社发项目管理服务有限公司受。上海市奉贤区中医医院的委托，采用。竞争性磋商方式实施采购的。...
# ...

# %%
data1[-50:]
# Out:
#                                                        id  \
# 172377                                              94595
# 172378                                              94621
# 172379                                              94692
# 172380                                            9469682
# 172381                                            9482914
# 172382                                            9482925
# 172383                                            9482930
# 172384                                            9486469
# 172385                                            9491319
# 172386                                              94925
# 172387                                            9501704
# 172388                                            9501707
# 172389                                              95038
# 172390                                              95047
# 172391                                              95081
# ...

# %%
data2 = data1[:172422]

# %%
data2
# Out:
#             id                                            content
# 0       100412  报送时间：2015年5月20日。谈判项目名称：宣化科技职业学院大门装修工程政府采购项目。谈判...
# 1       100586  ，采购项目名称：中国科学院生物物理研究所蛋白质与多肽制备鉴定系统采购项目，采购人名称：中国科...
# 2       100620  上海社发项目管理服务有限公司受。上海市奉贤区中医医院的委托，采用。竞争性磋商方式实施采购的。...
# 3       100888  ，广州有德招标代理有限公司（以下简称“采购代理机构”）受广州经济技术开发区国有资产投资公司（...
# 4       101009  北京中润达工程咨询有限公司受北京金隅科技学校的委托，就“北京金隅科技学校信息化建设---核心...
# ...        ...                                                ...
# 172417   99356  ，依据柳州市财政局政府采购计划（采购清单编号：柳政采1504008）的要求，广西云龙招标有限...
# 172418   99455  建设云南省中药材流通追溯体系平台项目（重新招标）中标公示。建设云南省中药材流通追溯体系平台项...
# 172419   99697  福建榕卫招标有限公司受福建亿榕信息技术有限公司的委托，就“营销档案管理项目劳务借用采购”项目...
# 172420   99900  一．采购人名称：安吉交通运输发展有限公司、北京城建道桥建设集团有限公司。二．采购项目名称：安...
# 172421   99998  一、采购项目名称：贺州市政务服务管理办公室“多规合一”审批服务大厅智能弱电系统工程，二、工期...
#
# [172422 rows x 2 columns]

# %%
data3 = data2.sort_values('id')

# %%
data3
# Out:
#             id                                            content
# 0       100412  报送时间：2015年5月20日。谈判项目名称：宣化科技职业学院大门装修工程政府采购项目。谈判...
# 1       100586  ，采购项目名称：中国科学院生物物理研究所蛋白质与多肽制备鉴定系统采购项目，采购人名称：中国科...
# 2       100620  上海社发项目管理服务有限公司受。上海市奉贤区中医医院的委托，采用。竞争性磋商方式实施采购的。...
# 3       100888  ，广州有德招标代理有限公司（以下简称“采购代理机构”）受广州经济技术开发区国有资产投资公司（...
# 4       101009  北京中润达工程咨询有限公司受北京金隅科技学校的委托，就“北京金隅科技学校信息化建设---核心...
# ...        ...                                                ...
# 172417   99356  ，依据柳州市财政局政府采购计划（采购清单编号：柳政采1504008）的要求，广西云龙招标有限...
# 172418   99455  建设云南省中药材流通追溯体系平台项目（重新招标）中标公示。建设云南省中药材流通追溯体系平台项...
# 172419   99697  福建榕卫招标有限公司受福建亿榕信息技术有限公司的委托，就“营销档案管理项目劳务借用采购”项目...
# 172420   99900  一．采购人名称：安吉交通运输发展有限公司、北京城建道桥建设集团有限公司。二．采购项目名称：安...
# 172421   99998  一、采购项目名称：贺州市政务服务管理办公室“多规合一”审批服务大厅智能弱电系统工程，二、工期...
#
# [172422 rows x 2 columns]

# %%
data3[['id']] = data3[['id']].astype('int')

# %%
data4 = data3.sort_values('id')

# %%
data4
# Out:
#               id                                            content
# 116857       313  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 167341       475  项目名称：央视国际网络有限公司外文办公区演播室系统建设项目摄录、大屏及灯光系统设备项目，招标...
# 171478       745  受天津大学委托，天津市泛亚工程机电设备咨询有限公司于2014年12月31日以公开招标方式，对...
# 171872       770  汕尾市公共资源交易中心（以下简称“集中采购机构”）受汕尾市公安局（以下简称“采购人”）的委托...
# 172182       814  关于韩城市基于基础数据资源为民服务系统项目中标公告，韩城市基于基础数据资源为民服务系统项目已...
# ...          ...                                                ...
# 166626  42048406  成都市文化广电旅游局村村通发射台智慧运维管理系统试点建设项目比选结果公告成都市文化广电旅游局...
# 166627  42048416  四川省成都市天府新区中共四川天府新区成都纪律检查工作委员会天府新区成都纪工委（监察工委、巡察...
# 166628  42048743  上海市崇明区长兴人民医院高清内窥镜诊疗系统采购项目中标结果公告(1)。项目编号：1825-1...
# 166629  42048781  杭州火车东站停车库车位引导系统提升改造工程中标结果公示。项目名称杭州火车东站停车库车位引导系...
# 166630  42048866  重庆公运南彭物流园11厂房冷链仓库改建保温系统和制冷系统EPC项目的中标候选人公示。重庆公运...
#
# [172422 rows x 2 columns]

# %%
data4.reset_index(inplace=True, drop=True)

# %%
data4
# Out:
#          index        id                                            content
# 0       116857       313  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 1       167341       475  项目名称：央视国际网络有限公司外文办公区演播室系统建设项目摄录、大屏及灯光系统设备项目，招标...
# 2       171478       745  受天津大学委托，天津市泛亚工程机电设备咨询有限公司于2014年12月31日以公开招标方式，对...
# 3       171872       770  汕尾市公共资源交易中心（以下简称“集中采购机构”）受汕尾市公安局（以下简称“采购人”）的委托...
# 4       172182       814  关于韩城市基于基础数据资源为民服务系统项目中标公告，韩城市基于基础数据资源为民服务系统项目已...
# ...        ...       ...                                                ...
# 172417  166626  42048406  成都市文化广电旅游局村村通发射台智慧运维管理系统试点建设项目比选结果公告成都市文化广电旅游局...
# 172418  166627  42048416  四川省成都市天府新区中共四川天府新区成都纪律检查工作委员会天府新区成都纪工委（监察工委、巡察...
# 172419  166628  42048743  上海市崇明区长兴人民医院高清内窥镜诊疗系统采购项目中标结果公告(1)。项目编号：1825-1...
# 172420  166629  42048781  杭州火车东站停车库车位引导系统提升改造工程中标结果公示。项目名称杭州火车东站停车库车位引导系...
# 172421  166630  42048866  重庆公运南彭物流园11厂房冷链仓库改建保温系统和制冷系统EPC项目的中标候选人公示。重庆公运...
#
# [172422 rows x 3 columns]

# %%
data4.drop(columns=['index'],inplace=True)

# %%
data4
# Out:
#               id                                            content
# 0            313  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 1            475  项目名称：央视国际网络有限公司外文办公区演播室系统建设项目摄录、大屏及灯光系统设备项目，招标...
# 2            745  受天津大学委托，天津市泛亚工程机电设备咨询有限公司于2014年12月31日以公开招标方式，对...
# 3            770  汕尾市公共资源交易中心（以下简称“集中采购机构”）受汕尾市公安局（以下简称“采购人”）的委托...
# 4            814  关于韩城市基于基础数据资源为民服务系统项目中标公告，韩城市基于基础数据资源为民服务系统项目已...
# ...          ...                                                ...
# 172417  42048406  成都市文化广电旅游局村村通发射台智慧运维管理系统试点建设项目比选结果公告成都市文化广电旅游局...
# 172418  42048416  四川省成都市天府新区中共四川天府新区成都纪律检查工作委员会天府新区成都纪工委（监察工委、巡察...
# 172419  42048743  上海市崇明区长兴人民医院高清内窥镜诊疗系统采购项目中标结果公告(1)。项目编号：1825-1...
# 172420  42048781  杭州火车东站停车库车位引导系统提升改造工程中标结果公示。项目名称杭州火车东站停车库车位引导系...
# 172421  42048866  重庆公运南彭物流园11厂房冷链仓库改建保温系统和制冷系统EPC项目的中标候选人公示。重庆公运...
#
# [172422 rows x 2 columns]

# %%
data4['content'][0]
# Out:
# 'st1\\：*{behavior：url(ieooui)}/*StyleDefinitions*/table.MsoNormalTable{mso-style-name：普通表格;mso-tstyle-rowband-size：0;mso-tstyle-colband-size：0;mso-style-noshow：yes;mso-style-parent："";mso-padding-alt：0cm5.4pt0cm5.4pt;mso-para-margin：0cm;mso-para-margin-bottom：.0001pt;mso-pagination：widow-orphan;font-size：10.0pt;font-family："TimesNewRoman";mso-fareast-font-family："TimesNewRoman";mso-ansi-language：0400;mso-fareast-language：0400;mso-bidi-language：0400;}河南省机电设备国际招标有限公司受安阳经开置业有限公司的委托，就滑县华泰新都城中央空调分户计费系统采购项目进行竞争性谈判采购，按规定程序进行了谈判，现就本次竞争性谈判的结果公示如下：，一、谈判项目名称及谈判编号。项目名称：滑县华泰新都城中央空调分户计费系统采购项目。<pstyle="LINE-HEIGHT：20pt;TEXT-INDENT：11.8pt;mso-char-i '

# %%
data4.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted.csv', index=False)

# %%
data5 = pd.read_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted.csv')

# %%
data5
# Out:
#               id                                            content
# 0            313  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 1            475  项目名称：央视国际网络有限公司外文办公区演播室系统建设项目摄录、大屏及灯光系统设备项目，招标...
# 2            745  受天津大学委托，天津市泛亚工程机电设备咨询有限公司于2014年12月31日以公开招标方式，对...
# 3            770  汕尾市公共资源交易中心（以下简称“集中采购机构”）受汕尾市公安局（以下简称“采购人”）的委托...
# 4            814  关于韩城市基于基础数据资源为民服务系统项目中标公告，韩城市基于基础数据资源为民服务系统项目已...
# ...          ...                                                ...
# 172417  42048406  成都市文化广电旅游局村村通发射台智慧运维管理系统试点建设项目比选结果公告成都市文化广电旅游局...
# 172418  42048416  四川省成都市天府新区中共四川天府新区成都纪律检查工作委员会天府新区成都纪工委（监察工委、巡察...
# 172419  42048743  上海市崇明区长兴人民医院高清内窥镜诊疗系统采购项目中标结果公告(1)。项目编号：1825-1...
# 172420  42048781  杭州火车东站停车库车位引导系统提升改造工程中标结果公示。项目名称杭州火车东站停车库车位引导系...
# 172421  42048866  重庆公运南彭物流园11厂房冷链仓库改建保温系统和制冷系统EPC项目的中标候选人公示。重庆公运...
#
# [172422 rows x 2 columns]

# %%
data6 = data5[:86211]

# %%
data6
# Out:
#              id                                            content
# 0           313  st1\：*{behavior：url(ieooui)}/*StyleDefinitions...
# 1           475  项目名称：央视国际网络有限公司外文办公区演播室系统建设项目摄录、大屏及灯光系统设备项目，招标...
# 2           745  受天津大学委托，天津市泛亚工程机电设备咨询有限公司于2014年12月31日以公开招标方式，对...
# 3           770  汕尾市公共资源交易中心（以下简称“集中采购机构”）受汕尾市公安局（以下简称“采购人”）的委托...
# 4           814  关于韩城市基于基础数据资源为民服务系统项目中标公告，韩城市基于基础数据资源为民服务系统项目已...
# ...         ...                                                ...
# 86206  25606148  海南师范大学-海南师范大学数字资源建设项目-中标公告。发布时间：2019-09-11。一、招...
# 86207  25606290  祥云公司承接山东富伦项目网络安全防护系统招标采购中标公告。招标名称祥云公司承接山东富伦项目网...
# 86208  25606301  祥云公司病毒防护系统采购中标公告。招标名称祥云公司病毒防护系统采购招标编号ZH-8902-1...
# 86209  25606699  研发中心2017年度“城镇污水厂恶臭气体治理集成技术产品开发”--除臭系统集中监控设备采购及...
# 86210  25606703  研发中心2018-科研管理软件平台升级维护竞价结果公示。采购在线竞价（项目编号：2018-Z...
#
# [86211 rows x 2 columns]

# %%
data6.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted_00.csv', index=False)

# %%
data7 = data5[86211:]

# %%
data7.to_csv('../linliquan/sofy_classify/wrong_data_idcontent_sorted_01.csv', index=False)
